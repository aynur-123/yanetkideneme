# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_palette('husl')
import matplotlib.pyplot as plt
# %matplotlib inline


data = pd.read_excel('yanetki.xlsx')

# %%
data.head()
# Out:
#     ilac_ad  tekrar  dozaj cinsiyet  yas  boy  kilo  vki kan_grub  \
# 0     parol       1     25        k   25  170    50  NaN       a+
# 1  afinitor       1     75        k   25  170    50  NaN       a+
# 2     parol       2     25        k   25  172    50  NaN       a+
# 3     parol       2     50        k   25  172    50  NaN       a+
# 4  afinitor       1     75        k   25  172    50  NaN       a+
#
#   kronik_rahatsizlik kullandığı_ilaclar
# 0              şeker                var
# 1              şeker                var
# 2              şeker                var
# 3              şeker                var
# 4              şeker                var

# %%
sns.pairplot(data)

# %%
data.corr()
# Out:
#           tekrar     dozaj       yas       boy      kilo  vki
# tekrar  1.000000  0.260732 -0.033394 -0.028353  0.102559  NaN
# dozaj   0.260732  1.000000 -0.163897  0.015342  0.348971  NaN
# yas    -0.033394 -0.163897  1.000000  0.570787  0.480192  NaN
# boy    -0.028353  0.015342  0.570787  1.000000  0.737682  NaN
# kilo    0.102559  0.348971  0.480192  0.737682  1.000000  NaN
# vki          NaN       NaN       NaN       NaN       NaN  NaN

# %%
sns.kdeplot(x=data.yas, y=data.kilo)
plt.show()

# %%
sns.jointplot(data=data, x="boy", y="yas", kind="kde")
sns.set_style("white")
plt.show()
